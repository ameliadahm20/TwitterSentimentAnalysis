# %% [markdown]
# ## EDA and visuals <a id="EDA"></a>
# [1. Distribution of tweets by product and sentiment](#Dist-tweets-prod)
#
# [2. Distribution of sentiment by product](#Dist-sent-prod)
#
# [3. Word frequencies overall](#Word-freq-overall)
#
# [4. Word frequencies by product and valence](#Word-freq-by-prod)
#
# [5. Termite plot of words overall, by product and valence](#termite)

# %%
# import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as sp
# %matplotlib inline

# %% [markdown]
# * Importing the lemmatized tweets with the sentiment values calculated to look at word frequencies and distributions

# %%
df = pd.read_csv('data/lemmatized_and_sentiment_tweets.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                              tweet  \
# 0           0  ['wesley83', 'have', '3G', 'iPhone', '3', 'hrs...
# 1           1  ['jessedee', 'Know', 'fludapp', 'Awesome', 'iP...
# 2           2  ['swonderlin', 'not', 'wait', 'iPad', '2', 'al...
# 3           3  ['sxsw', 'hope', 'year', 'festival', 't', 'cra...
# 4           4  ['sxtxstate', 'great', 'stuff', 'Fri', 'SXSW',...
#
#              product_  emotion  \
# 0              iPhone        0
# 1  iPad or iPhone App        1
# 2                iPad        1
# 3  iPad or iPhone App        0
# 4              Google        1
#
#                                    lemmatizer_tweets  textblob_polarity  \
# 0  wesley83 have 3G iPhone 3 hr tweeting RISE Aus...          -0.200000
# 1  jessedee Know fludapp Awesome iPad iPhone app ...           0.466667
# 2  swonderlin not wait iPad 2 also should sale do...          -0.155556
# 3  sxsw hope year festival t crashy this year iPh...           0.000000
# 4  sxtxstate great stuff Fri SXSW Marissa Mayer G...           0.800000
#
#    textblob_subjectivity  vs_neg  vs_neu  vs_pos  vs_compound
# 0               0.400000   0.223   0.777   0.000      -0.6486
# 1               0.933333   0.000   0.528   0.472       0.9100
# 2               0.288889   0.000   1.000   0.000       0.0000
# 3               0.000000   0.000   0.596   0.404       0.7269
# 4               0.750000   0.000   0.796   0.204       0.6249

# %%
df.drop(labels='Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# ## Distribution of tweets by product <a id="Dist-tweets-prod"></a>
# ##### [(back to top)](#EDA)

# %%
plt.figure(figsize=(10,5))
chart = sns.countplot(x='product_', data=df)
chart.set_xticklabels(labels=['iPhone','iPad or iPhone app','iPad','Google','Unknown',
 'Android','Apple','Android App','Other Google product or service','Other Apple product or service'], rotation=45);
chart.set_xlabel('Product');
chart.set_ylabel('Number of Tweets');
chart.set_title('Number of tweets per product');

# %% [markdown]
# #### Interpretation:
# * Unknown product is dominating in terms of volumne - what is in this dataset if not talking about the products?
# * The multitude of categories for apple products distorts the scale by products.  Combining the categories below and re-examining

# %%
cond_list = [df['product_'] == 'Google',
             df['product_'] == 'Other Google product or service',
            df['product_'] == 'Unknown',
            df['product_'] == 'Android',
            df['product_'] == 'Android App']
choice_list = ['Google','Google','Unknown','Android','Android']


df['product_agg'] = np.select(cond_list,choice_list, 'Apple')

# %%
df['product_'].value_counts()
# Out:
# Unknown                            5801
# iPad                                946
# Apple                               661
# iPad or iPhone App                  470
# Google                              430
# iPhone                              297
# Other Google product or service     293
# Android App                          81
# Android                              78
# Other Apple product or service       35
# Name: product_, dtype: int64

# %%
df['product_agg'].value_counts()
# Out:
# Unknown    5801
# Apple      2409
# Google      723
# Android     159
# Name: product_agg, dtype: int64

# %%
plt.figure(figsize=(10,5))
chart = sns.countplot(x='product_agg', data=df, )
chart.set_xticklabels(labels=['Apple','Google','Unknown','Android'], rotation=45);
chart.set_xlabel('Product');
chart.set_ylabel('Number of Tweets');
chart.set_title('Number of tweets per product');

# %% [markdown]
# #### Interpretation:
# * Unknown still dominates - more than 2x Apple.  What are these tweets about?
# * After combining Apple has more than 3x the number of tweets than Google.
# * Android is tiny fraction.

# %% [markdown]
# #### Calculating mean and median sentiment scores by aggregated product categories below.

# %%
df.head()
# Out:
#                                                tweet            product_  \
# 0  ['wesley83', 'have', '3G', 'iPhone', '3', 'hrs...              iPhone
# 1  ['jessedee', 'Know', 'fludapp', 'Awesome', 'iP...  iPad or iPhone App
# 2  ['swonderlin', 'not', 'wait', 'iPad', '2', 'al...                iPad
# 3  ['sxsw', 'hope', 'year', 'festival', 't', 'cra...  iPad or iPhone App
# 4  ['sxtxstate', 'great', 'stuff', 'Fri', 'SXSW',...              Google
#
#    emotion                                  lemmatizer_tweets  \
# 0        0  wesley83 have 3G iPhone 3 hr tweeting RISE Aus...
# 1        1  jessedee Know fludapp Awesome iPad iPhone app ...
# 2        1  swonderlin not wait iPad 2 also should sale do...
# 3        0  sxsw hope year festival t crashy this year iPh...
# 4        1  sxtxstate great stuff Fri SXSW Marissa Mayer G...
#
#    textblob_polarity  textblob_subjectivity  vs_neg  vs_neu  vs_pos  \
# 0          -0.200000               0.400000   0.223   0.777   0.000
# 1           0.466667               0.933333   0.000   0.528   0.472
# 2          -0.155556               0.288889   0.000   1.000   0.000
# 3           0.000000               0.000000   0.000   0.596   0.404
# 4           0.800000               0.750000   0.000   0.796   0.204
#
#    vs_compound product_agg
# 0      -0.6486       Apple
# 1       0.9100       Apple
# 2       0.0000       Apple
# 3       0.7269       Apple
# 4       0.6249      Google

# %%
#Creating a function to compare mean and median sentiment across the major product categories
#Provided a sentiment metric it returns the group means, ANOVA, group medians, kruskall Wallis
#and graphs the mean sentiment by product
def bivar_analyzer(sent_met):
    apple = df.loc[df['product_agg'] == 'Apple', sent_met]
    google = df.loc[df['product_agg'] == 'Google', sent_met]
    android = df.loc[df['product_agg'] == 'Android', sent_met]
    unknown = df.loc[df['product_agg'] == 'Unknown', sent_met]
    
    a = df.groupby(['product_agg'])[sent_met].mean()
    print(f'Mean {sent_met} by product')
    print(a)
    print(sp.f_oneway(apple, google, android, unknown))
    print(f'Median {sent_met} by product')
    print(df.groupby(['product_agg'])[sent_met].median())
    print(sp.kruskal(apple, google, android, unknown))
    
    plt.figure(figsize=(10,5))
    chart = sns.barplot(x=a.index,y=a, data=df, )
    chart.set_xticklabels(labels=a.index, rotation=45);
    chart.set_xlabel('Product');
    chart.set_ylabel(f'Mean {sent_met}');
    chart.set_title(f'Mean {sent_met} by product');

# %% [markdown]
# #### Applying bivar analyzer on textblob's polarity
# * polarity ranges from -1 to 1.  Positive values are positive sentiment, negative - negative sentiment.

# %%
bivar_analyzer('textblob_polarity')
# Out:
# Mean textblob_polarity by product
# product_agg
# Android    0.240113
# Apple      0.183993
# Google     0.187189
# Unknown    0.103194
# Name: textblob_polarity, dtype: float64
# F_onewayResult(statistic=72.66119770092284, pvalue=1.9599549661549273e-46)
# Median textblob_polarity by product
# product_agg
# Android    0.200000
# Apple      0.125000
# Google     0.136364
# Unknown    0.000000
# Name: textblob_polarity, dtype: float64
# KruskalResult(statistic=258.86652105012877, pvalue=7.906699745660572e-56)

# %% [markdown]
# * Significantly different score.
# * Tweets without a specific product were the lowest mean polarity.
# * Android, though the smallest volume of tweets had highest mean.
# * Apple and Google roughly equal mean polarity.
#
# * Given this is a mean probably better to breakout into positive and negative so as to specifically investigate those situations

# %% [markdown]
# #### Applying bivar analyzer on textblob's subjectivity rating
# * Subjectivity rates whether the message expresses a personal opinion (1) or factual information (0).

# %%
bivar_analyzer('textblob_subjectivity')
# Out:
# Mean textblob_subjectivity by product
# product_agg
# Android    0.434576
# Apple      0.403356
# Google     0.400306
# Unknown    0.292621
# Name: textblob_subjectivity, dtype: float64
# F_onewayResult(statistic=92.22118718008055, pvalue=8.661170289683443e-59)
# Median textblob_subjectivity by product
# product_agg
# Android    0.475000
# Apple      0.450000
# Google     0.408333
# Unknown    0.260606
# Name: textblob_subjectivity, dtype: float64
# KruskalResult(statistic=278.0070410776856, pvalue=5.715574003960698e-60)

# %% [markdown]
# * Significantly different means/medians. Looking at raw means roughly equal subjectivity between named product categories and they tend to be more subjective than the unknown product.

# %% [markdown]
# #### Applying bivar analyzer to vander sentiment's negative rating
# * Rates the percentage negative of the tweet.  Ranges from 0 to 1.

# %%
bivar_analyzer('vs_neg')
# Out:
# Mean vs_neg by product
# product_agg
# Android    0.025572
# Apple      0.042899
# Google     0.031533
# Unknown    0.030386
# Name: vs_neg, dtype: float64
# F_onewayResult(statistic=15.167096905650649, pvalue=7.644024880781393e-10)
# Median vs_neg by product
# product_agg
# Android    0.0
# Apple      0.0
# Google     0.0
# Unknown    0.0
# Name: vs_neg, dtype: float64
# KruskalResult(statistic=52.39334429331721, pvalue=2.4692885033332857e-11)

# %% [markdown]
# * Apple has the highest mean negative score - investigate by product breakdown
# * Google and unknown are roughly equal
# * Android, following on the polarity above, have the lowest % negative.

# %% [markdown]
# #### Applying bivar analyzer to vander sentiment's neutral rating
# * Rates the percentage neutral of the tweet.  Ranges from 0 to 1.

# %%
bivar_analyzer('vs_neu')
# Out:
# Mean vs_neu by product
# product_agg
# Android    0.755711
# Apple      0.796999
# Google     0.792346
# Unknown    0.868360
# Name: vs_neu, dtype: float64
# F_onewayResult(statistic=167.25803152036718, pvalue=1.5282622371613551e-105)
# Median vs_neu by product
# product_agg
# Android    0.778
# Apple      0.795
# Google     0.796
# Unknown    0.890
# Name: vs_neu, dtype: float64
# KruskalResult(statistic=476.93925175452216, pvalue=4.74282078425606e-103)

# %% [markdown]
# * Significantly different but the absolute magnitude of difference isn't that great between Android, Apple and Google.
# * Unknown products 7 points higher on average.

# %% [markdown]
# #### Applying bivar analyzer to vander sentiment's positive rating
# * Rates the percentage positive of the tweet.  Ranges from 0 to 1.

# %%
bivar_analyzer('vs_pos')
# Out:
# Mean vs_pos by product
# product_agg
# Android    0.218717
# Apple      0.160098
# Google     0.176119
# Unknown    0.101251
# Name: vs_pos, dtype: float64
# F_onewayResult(statistic=155.76177500552683, pvalue=1.9039433405980362e-98)
# Median vs_pos by product
# product_agg
# Android    0.203
# Apple      0.156
# Google     0.167
# Unknown    0.000
# Name: vs_pos, dtype: float64
# KruskalResult(statistic=440.44618466655436, pvalue=3.829970213407436e-95)

# %% [markdown]
# * Android the most positive
# * Apple lowest of the main products.
# * Unknown lowest positive

# %% [markdown]
# #### Applying bivar analyzer to vander sentiment's compound rating
# * Sum of all the lexicon ratings which have been normalized between -1 (most extreme negative) and 1 (most extreme positive)

# %%
bivar_analyzer('vs_compound')
# Out:
# Mean vs_compound by product
# product_agg
# Android    0.375961
# Apple      0.259765
# Google     0.310995
# Unknown    0.158427
# Name: vs_compound, dtype: float64
# F_onewayResult(statistic=82.77447302183036, pvalue=7.873614179286613e-53)
# Median vs_compound by product
# product_agg
# Android    0.4404
# Apple      0.3182
# Google     0.3818
# Unknown    0.0000
# Name: vs_compound, dtype: float64
# KruskalResult(statistic=269.0005657016715, pvalue=5.07798680791687e-58)

# %% [markdown]
# * Android overall most positive
# * Apple least positive of major products
# * Unknown has lowest mean

# %% [markdown]
# ## Overall impressions:
# * Unknown tweets are the most neutral and least subjective - probably providing information
# * Though the volume of tweets is really low Android has highest mean positivity
# * Apple dominates in terms of volume but also lowest positivity and highest negativity

# %% [markdown]
# #### Getting all the neg, neu and pos for each product on one graph - use sns.barplot with hue - need to reshape to plot mean value by product with the hue set to the appropriate valence.

# %%
a = df.groupby(['product_agg'])['vs_neg'].mean()
b = df.groupby(['product_agg'])['vs_neu'].mean()
c = df.groupby(['product_agg'])['vs_pos'].mean()

# %%
vs_neg = pd.DataFrame(data=a)
vs_neg['metric'] = 'VS negative'
vs_neg.rename(columns={"vs_neg":"mean_rating"},inplace=True)
vs_neg.reset_index(inplace=True)

vs_neu = pd.DataFrame(data=b)
vs_neu['metric'] = 'VS neutral'
vs_neu.rename(columns={"vs_neu":"mean_rating"},inplace=True)
vs_neu.reset_index(inplace=True)

vs_pos = pd.DataFrame(data=c)
vs_pos['metric'] = 'VS positive'
vs_pos.rename(columns={"vs_pos":"mean_rating"},inplace=True)
vs_pos.reset_index(inplace=True)

# %%
intermediate = vs_neg.merge(vs_neu, how='outer')

# %%
stacked = intermediate.merge(vs_pos, how='outer')

# %%
plt.figure(figsize=(10,5))
chart = sns.barplot(x="product_agg", y="mean_rating", hue="metric", data=stacked)
chart.set_xlabel('Product');
chart.set_ylabel('Mean Rating');
chart.set_title('Mean rating by product')
chart.legend(loc='best');

# %% [markdown]
# * The scale of neutral makes it hard to see what's going on with positive and negative.
# * Probably won't use.

# %% [markdown]
# #### Generally speaking apple the most negative reviews.
# * As there were several apple subcategories will assess if there are differences in the negativity score by subcat.

# %%
df_apple = df.loc[df['product_agg'] == 'Apple',:]

# %%
df['product_'].value_counts()
# Out:
# Unknown                            5801
# iPad                                946
# Apple                               661
# iPad or iPhone App                  470
# Google                              430
# iPhone                              297
# Other Google product or service     293
# Android App                          81
# Android                              78
# Other Apple product or service       35
# Name: product_, dtype: int64

# %%
iPad = df_apple.loc[df_apple['product_'] == 'iPad', 'vs_neg']
apple_app = df_apple.loc[df_apple['product_'] == 'iPad or iPhone App', 'vs_neg']
iPhone = df_apple.loc[df_apple['product_'] == 'iPhone', 'vs_neg']
Other_apple = df_apple.loc[df_apple['product_'] == 'Other Apple product or service', 'vs_neg']

a = df_apple.groupby(['product_'])['vs_neg'].mean()
print('Mean VS neg by apple product')
print(a)
print(sp.f_oneway(iPad, apple_app, iPhone, Other_apple))
print('Median VS neg by apple product')
print(df_apple.groupby(['product_'])['vs_neg'].median())
print(sp.kruskal(iPad, apple_app, iPhone, Other_apple))

plt.figure(figsize=(10,5))
chart = sns.barplot(x=a.index,y=a, data=df_apple, )
chart.set_xticklabels(labels=a.index, rotation=45);
chart.set_xlabel('Product');
chart.set_ylabel('Mean VS neg');
chart.set_title('Mean VS neg by product');
# Out:
# Mean VS neg by apple product
# product_
# Apple                             0.038233
# Other Apple product or service    0.043343
# iPad                              0.042960
# iPad or iPhone App                0.029857
# iPhone                            0.073673
# Name: vs_neg, dtype: float64
# F_onewayResult(statistic=14.939143039082458, pvalue=1.326413349889096e-09)
# Median VS neg by apple product
# product_
# Apple                             0.0
# Other Apple product or service    0.0
# iPad                              0.0
# iPad or iPhone App                0.0
# iPhone                            0.0
# Name: vs_neg, dtype: float64
# KruskalResult(statistic=41.589478040156365, pvalue=4.903213939772419e-09)

# %% [markdown]
# * Of the apple products the most negative is the iphone.  Note the scale of the y-axis.  This is relatively true but not necessarily absolutely true.

# %% [markdown]
# ## Distribution of Sentiment by Product <a id="Dist-sent-prod"></a>
# ##### [(back to top)](#EDA)

# %%
plt.figure(figsize=(12, 8))
ax = sns.distplot(df['vs_pos'][df['product_agg'] == 'Apple'], label='Apple', color='orange');
ax = sns.distplot(df['vs_pos'][df['product_agg'] =='Android'], label='Android', color='green');
ax = sns.distplot(df['vs_pos'][df['product_agg'] == 'Google'], label='Google', color='purple');
ax.set_title('vs_pos by product_agg', fontsize=20);
ax.set_ylabel('density', fontsize=16);
ax.set_xlabel('vs_pos', fontsize=16);
ax.legend(prop=dict(size=14));

# %%
plt.figure(figsize=(12, 8))
ax = sns.distplot(df['vs_neu'][df['product_agg'] == 'Apple'], label='Apple', color='orange');
ax = sns.distplot(df['vs_neu'][df['product_agg'] =='Android'], label='Android', color='green');
ax = sns.distplot(df['vs_neu'][df['product_agg'] == 'Google'], label='Google', color='purple');
ax.set_title('vs_neu by product_agg', fontsize=20);
ax.set_ylabel('density', fontsize=16);
ax.set_xlabel('vs_neu', fontsize=16);
ax.legend(prop=dict(size=14));

# %%
kde_dict = {'bw': .0000001}

# %%
plt.figure(figsize=(12, 8))
ax = sns.distplot(df['vs_neg'][df['product_agg'] == 'Apple'], label='Apple', color='orange', kde_kws=kde_dict);
ax = sns.distplot(df['vs_neg'][df['product_agg'] =='Android'], label='Android', color='green', kde_kws=kde_dict);
ax = sns.distplot(df['vs_neg'][df['product_agg'] == 'Google'], label='Google', color='purple', kde_kws=kde_dict);
ax.set_title('vs_neg by product_agg', fontsize=20);
ax.set_ylabel('density', fontsize=16);
ax.set_xlabel('vs_neg', fontsize=16);
ax.legend(prop=dict(size=14));

# %% [markdown]
# ## Word counts overall <a id="Word-freq-overall"></a>
# ##### [(back to top)](#EDA)

# %% [markdown]
# There was something going on with the format of previous tokenization and lemmatization - couldn't get the column into a flat list for counting.  Here taking the original tweet column and merging with the dataset with the valences and aggregated product categories for subsetting.  Function below includes tokenization, stop word removal, casing and lemmatization.

# %%
df_original = pd.read_csv('data/tweets.csv', encoding = "ISO-8859-1")
df_original.tail()
# Out:
#                                              tweet_text  \
# 9088                      Ipad everywhere. #SXSW {link}
# 9089  Wave, buzz... RT @mention We interrupt your re...
# 9090  Google's Zeiger, a physician never reported po...
# 9091  Some Verizon iPhone customers complained their...
# 9092  Ï¡Ïàü_ÊÎÒ£Áââ_£â_ÛâRT @...
#
#      emotion_in_tweet_is_directed_at  \
# 9088                            iPad
# 9089                             NaN
# 9090                             NaN
# 9091                             NaN
# 9092                             NaN
#
#      is_there_an_emotion_directed_at_a_brand_or_product
# 9088                                   Positive emotion
# 9089                 No emotion toward brand or product
# 9090                 No emotion toward brand or product
# 9091                 No emotion toward brand or product
# 9092                 No emotion toward brand or product

# %%
# rename columns
df_original.rename(columns ={'tweet_text': 'tweet_original'}, 
                   inplace = True)

# %%
df_tweet = df_original['tweet_original']
df_tweet.dropna(inplace=True)

# %%
pd.options.display.max_rows = 9100

# %%
df_original['tweet_original']
# Out:
# 0       .@wesley83 I have a 3G iPhone. After 3 hrs twe...
# 1       @jessedee Know about @fludapp ? Awesome iPad/i...
# 2       @swonderlin Can not wait for #iPad 2 also. The...
# 3       @sxsw I hope this year's festival isn't as cra...
# 4       @sxtxstate great stuff on Fri #SXSW: Marissa M...
# 5       @teachntech00 New iPad Apps For #SpeechTherapy...
# 7       #SXSW is just starting, #CTIA is around the co...
# 8       Beautifully smart and simple idea RT @madebyma...
# 9       Counting down the days to #sxsw plus strong Ca...
# 10      Excited to meet the @samsungmobileus at #sxsw ...
# 11      Find &amp; Start Impromptu Parties at #SXSW Wi...
# 12      Foursquare ups the game, just in time for #SXS...
# 13      Gotta love this #SXSW Google Calendar featurin...
# 14      Great #sxsw ipad app from @madebymany: http://...
# 15      haha, awesomely rad iPad app by @madebymany ht...
# 16      Holler Gram for iPad on the iTunes App Store -...
# 17      I just noticed DST is coming this weekend. How...
# 18      Just added my #SXSW flights to @planely. Match...
# 19      Must have #SXSW app! RT @malbonster: Lovely re...
# 20      Need to buy an iPad2 while I'm in Austin at #s...
# 21      Oh. My. God. The #SXSW app for iPad is pure, u...
# 22      Okay, this is really it: yay new @Foursquare f...
# 78      iPad2? RT @mention Droid &amp; Mac here :) RT ...
# 79      Launching @mention #SxSW? RT @mention @mention...
# 80      New Post: @mention iPhone app makes it easy to...
# 81      Nice that @mention iPhone app is behaving toda...
# 82      Nice!  RT @mention Apple opening popup store f...
# 83      Nice!! RT @mention Hey, Apple fans! Get a peek...
# 84      one thing @mention is doing so great is get a ...
# 85      Stay tune @mention showcase #H4ckers {link} #SXSW
# 86      Thank you @mention @mention for the #touchings...
# 87      Thank you @mention for an awesome #sxsw party!...
# 88      Thanks RT @mention If you're trying to contact...
# 89      Thanks to @mention for her mention of our new ...
# 90      Thanks to @mention for publishing the news of ...
# 91      Thanks to @mention for publishing the news of ...
# 92      What !?!? @mention  #SXSW does not provide iPh...
# 93      Wonder if @mention &amp; @mention will be in t...
# 94      Wonder if @mention is putting tips from the @m...
# 95      XMAS!! RT @mention Shiny new @mention @mention...
# 96      Yai!!! RT @mention New #UberSocial for #iPhone...
# 97      Yes!!! RT @mention hey @mention , i've got ano...
# 98      Fast, Fun &amp; Future: @mention of Google pre...
# 99      GSD&amp;M &amp; Google's Industry Party Tonigh...
# 100     New buzz? &quot;@mention Google to Launch Majo...
# 101     Headline: &quot;#iPad 2 is the Must-Have Gadge...
# 102     ÛÏ@mention &quot;Apple has opened a pop-up st...
# 103     Know that &quot;dataviz&quot; translates to &q...
# 104     .@mention &quot;Google launched checkins a mon...
# 105     .@mention &quot;Google launched checkins a mon...
# 106     ÛÏ@mention &quot;Google before you tweet&quot...
# 107     Attending &quot;left brain search = Google, Ri...
# 108     #HP opens &quot;Mobile Park&quot;  &amp; Conte...
# 109     Kawasaki: &quot;Not C.S. Lewis level reasoning...
# 110     Kawasaki: &quot;pagemaker saved Apple.&quot; O...
# 111     Kawasaki: &quot;pagemaker saved Apple.&quot; O...
# 112     Spark for #android is up for a #teamandroid aw...
# 113     Unboxing. #Apple #sxsw  @mention Apple Store, ...
# 114     #SXSW and #Apple iPad 2's are great, but thoug...
# 115     At #SXSW, #Apple schools the #marketing expert...
# 116     At #SXSW, #Apple schools the marketing experts...
# 117     At #SXSW, #Apple schools the marketing experts...
# 118     Temporary #apple store is def not a tent, it's...
# 119     Temporary #Apple store on 6th and Congress for...
# 120     ÛÏ@mention #Apple wins #SXSW {link} Opening a...
# 121     #iPad and #Austin are trending today. Have fun...
# 122     Headed to #Austin for #SXSW? Check out my map ...
# 123     Funny how #Austin is trending but not #SXSW. O...
# 124     Christian #iPad #iPhone devs I want to talk to...
# 125     #sxsw #ux #ipad #uxdes remember to ultimately ...
# 126     The Apple #iPAD2  has taken #SxSW and #Austin ...
# 127               I can haz #iPad2 ifrom #SxSW Gr8 {link}
# 128     Stacks of #ipad2's waiting to be bought at #sx...
# 129     #Google's #Mobile Future, and the Elusive 'Pow...
# 130     For those #notatSXSW (or at #SXSW), here's {li...
# 131     Does your #SmallBiz need reviews to play on Go...
# 132     Does your #SmallBiz need reviews to play on Go...
# 133     #Samsung, #Sony follow #Apple, #HP lead @menti...
# 134     #Samsung, #Sony follow #Apple, #HP lead @menti...
# 135     Take that #SXSW ! RT @mention Major South Kore...
# 136     Beautiful #sxsw (@mention Apple Store, SXSW) [...
# 137     Q1 Was at #sxsw #sxswi for prep. Amazing pre p...
# 138     Any other #Sxsw accounts I need to follow or a...
# 139     Headed to #sxsw and want to share/gather conta...
# 140     Headed to #sxsw and want to share/gather conta...
# 141     BTW - The #sxsw Apple store is sold out of all...
# 142     Must have #SXSW app! RT @mention Lovely review...
# 143     Temporary #sxsw apple store. Apple being sneak...
# 144     Anyone at #sxsw been by the pop-up Apple store...
# 145     ÛÏ@mention #sxsw beta testing interactive boo...
# 146     Apple won #SxSW from day one. Seeing a TON of ...
# 147     #fastball #sxsw Giving away two NEW Ipad2 wifi...
# 148     Anyone at #sxsw had a chance to check out the ...
# 149     ÛÏ@mention #sxsw ipad store sold out of every...
# 150     ÛÏ@mention #sxsw ipad store sold out of every...
# 151     Offered a #sxsw ipad promo to ninjafinder user...
# 152     @mention  #SXSW is an Austin conference. Do a ...
# 153     Anyone at #sxsw know if apple will be (or is) ...
# 154     Anyone at #SXSW know if the apple store has ha...
# 155     Marc Ecko #SXSW launches #iPhone app. to autod...
# 156     #POURsite #SXSW learning about the life-changi...
# 157     @mention  #SXSW LonelyPlanet Austin guide for ...
# 158     More free #SXSW mp3 downloads, this time from ...
# 159     Anyone at #sxsw or heading to aclu event seen ...
# 160     @mention  #SXSW prompt for memory: go to Googl...
# 161     The Apple #SXSW store still has iPad 2's and s...
# 162                         Essential #sxsw tools: {link}
# 163     Just left #sxsw tradeshow demo of @mention at ...
# 164     Following #sxsw Tweets on Google Realtime, fou...
# 165     Anyone at #sxsw want an iPad 2? I'm in line an...
# 166     Anyone at #sxsw want to make a quick hundred d...
# 167     Solving a #SXSW-induced iPhone-in-toilet crisi...
# 168     Monday at #sxsw: barry diller, new york times,...
# 169     Attending #sxsw? Austin Guide by @mention is n...
# 170     Seriously #sxsw? Did you do any testing on the...
# 171     Ready for #SXSW?! Here are some iPhone apps 2 ...
# 172     ipad2 and #sxsw...a conflagration of doofusnes...
# 173     attention #sxsw'ers - {link} - rumored pop-up ...
# 174     I went to #sxswi and all I won was this lousy ...
# 175     Hey #sxsw #sxswi folks. If you want to learn a...
# 176     Attending #SXSWi? Work in iPhone / iPad game d...
# 177     This is a #WINNING picture #android #google #s...
# 178     GSD&amp;M + Google 7-10. RT @mention What's th...
# 179     GSD&amp;M + Google Industry Party #SXSW @menti...
# 180     You spent $1,000+ to come to SXSW. \n\nYou've ...
# 181     #sxsw day 1 - Marissa Mayer: Google Will Conne...
# 182     Behind on 100s of emails? Give them all 1 line...
# 183     It's like 10pm at night and there is a line ar...
# 184     .@mention 1154 free songs from #SXSW (this yea...
# 185     more than 150 million mobile users for Google ...
# 186     Currently 150 people in line at the &quot;Pop ...
# 187     Only iPad 2 available at #sxsw is the 64GB wif...
# 188     ÷¼ We love 2 entertain youÛ_Please donÛªt b...
# 189     Less than 2 hours until we announce the detail...
# 190     I'm up to 2 iPad 2s seen in the wild. Both peo...
# 191                  (The iPad 2 queue at #sxsw of course
# 192     The #iPad 2 Takes Over #SXSW [VIDEO] /by @ment...
# 193     many iPad 2's snapping away at the keynote sli...
# 194     Apple has 200M users' credit cards sync'd with...
# 195     Having my 2nd cocktail &quot;Texas Snowflake&q...
# 196     New Post: 3 iPhone Apps We'll Be Using at Sout...
# 197     New Post: 3 iPhone Apps We'll Be Using at Sout...
# 198     sweet new 3-d google maps demo going on in bal...
# 199     More than 35 million miles per day are driving...
# 200     rt ' It's 4 p.m. and the #iPad2 line at the Ap...
# 201     U = smart 4 packing an extra :) RT @mention On...
# 202     Wonder if 4sqwill attempt to block GoWalla cro...
# 203     #SXSW day 5 at the #apple store and there's st...
# 204     Check out 5 Steps to Bulletproof UX Strategy a...
# 205     Wandering 6th street with the girls. Stopped f...
# 206     If you're a band at #SXSW and want to share a ...
# 207     We've got a busy week ahead: Our new book on #...
# 208     I believe a few went to Aussies at #sxsw RT @m...
# 209     ÛÏ@mention A Google Spreadsheet of over 270 p...
# 210     There was a guy in line for Apple's pop-up sto...
# 211     if u have a iPhone you don't need a car'-use z...
# 212     I've seen a lot of tablets here, every single ...
# 213     Receiving a lot of @mention messages telling m...
# 214     Picked up a Mophie battery case 4 my iPhone in...
# 215     Now thats a NEWS :P RT@mention Google to Launc...
# 216     Just took a piss at the trade show, iPad in on...
# 217     Not to be a rumor monger, but this was a good ...
# 218          HOBO WITH A SHOTGUN iPhone game {link} #sxsw
# 219     Hobo with A Shotgun video game coming to iPad/...
# 220     build out a store in less than 24 hours and ha...
# 221     Just took a survey on iPhone while in Starbuck...
# 222     Apple has a temporary Retail Store in Austin f...
# 223     Just read about #GroupMe at #SXSW...sounds lik...
# 224     Wondering about Circles? &gt; Google to reveal...
# 225     google is about search, but local' marissa may...
# 226     Wondering about street closures during SXSW? W...
# 227     Is Google about to have another go at social w...
# 228     Questions about what's inside the iPad 2? Fire...
# 229     Paraormal activity: Sanctuary iphone game. Ske...
# 230     Apple IIe ad in the '85 SI swimsuit issue at a...
# 231     Flipboard Adds Instagram Photos and Social Sea...
# 232     Spent the aftrnoon on a frozen lake photograph...
# 233     If iPhone alarms botch the timechange, how man...
# 234     Shouts to all the ladies holding up their iPad...
# 235     Dj hoodie allen, with all due respect, you sho...
# 236     I meant I also wish I  at #SXSW #dyac stupid i...
# 237     Just what America needs. RT @mention Google to...
# 238     Audioboo: American Dream or Bust {link} #iPad ...
# 239     Skifta is an app-based media shifting service ...
# 240     Rumors of an Apple store opening for #SXSW at ...
# 241     What does an Apple security guy after he locks...
# 242     What does an Apple security guy after he locks...
# 243     How I got an iPad 2 during #SXSW!  {link} cc @...
# 244     picked up an ipad 2 at the #sxsw pop up  apple...
# 245     Brilliant and enlightening game mechanics pres...
# 246     GSD&amp;M and Google.....sitting in a tree {li...
# 247     @mention  and here's a pic of you winning your...
# 248     My iPhone and I are both VERY thirsty! #sxsw (...
# 249     My iPhone and I are both VERY thirsty! #sxsw (...
# 250     I came in and left #sxsw with my iPhone playin...
# 251       marketing and sales GENIUS: {link} #Apple #SXSW
# 252     Arduino + android = Flaming skulls  {link} Ref...
# 253     Reminder: Android and Chrome TTS talk @mention...
# 254     iPad 2 vs Android vs The World : Panel at #SXS...
# 255     Backupify Announces CloudSight Search, the Fir...
# 256     Google is announcing a social network &quot;Ci...
# 257     Do I need any more for #sxsw! ipad, iphone, la...
# 258     Did u see anything on Google's Circles at the ...
# 259     The #SXSW app for my iPhone is ridiculous. It'...
# 260     Our #sxsw app is now on #android :D huge props...
# 261     Found the app kyping my iPhone's geolocation &...
# 262     the #SXSW app on the iPhone is live. RSVP for ...
# 263     My iPhone app screen for #sxsw what am I missi...
# 264     Love this app! So awesome. RT @mention Must se...
# 265     The #SXSW Apple &quot;pop-up&quot; store was n...
# 266     Say what? Apple #sxsw popup store in Austin! {...
# 267     BREAKING: Apple announces partnership w/porn i...
# 268     Of course Apple built a temp store in Austin. ...
# 269     Love that Apple didn't let something like not ...
# 270     Surprise! Apple has opened a pop-up store in A...
# 271     Surprise! Apple has opened a pop-up store in A...
# 272     Surprise! Apple has opened a pop-up store in A...
# 273     Surprise! Apple has opened a pop-up store in A...
# 274     #technews Apple heads to SXSW, sets up tempora...
# 275     ÛÏ@mention Apple is a great example of a reta...
# 276     ÛÏ@mention Apple is opening up a temporary st...
# 277     ÛÏ@mention Apple is opening up a temporary st...
# 278     #technews Apple Opening Pop-Up Store In Austin...
# 279     #technews Apple Opening Pop-Up Store in Austin...
# 280     The #sxsw Apple Popup Store is open at noon, h...
# 281     #technews Apple saves SXSW, set to open pop-up...
# 282     At #SXSW, Apple schools the marketing experts ...
# 283     At #SXSW, Apple schools the marketing experts ...
# 284     At #SXSW, Apple schools the marketing experts ...
# 285     At #SXSW, Apple schools the marketing experts ...
# 286     At #SXSW, Apple schools the marketing experts ...
# 287     At #SXSW, Apple schools the marketing experts ...
# 288     ÛÏ@mention Apple store downtown Austin open t...
# 289     ÛÏ@mention Apple store downtown Austin open t...
# 290     @mention  Apple Store on Congress  {link} #sxs...
# 291     &quot;The Apple store at the mall on Sunday is...
# 292     2wks only Apple Store in 6th Austin street is ...
# 293     A special Apple store: opening at 6th and Cong...
# 294     Makeshift apple store at 6th and congress. You...
# 295     Temporary Apple store at #sxsw - huge line. {l...
# 296     Temporary Apple store at SXSW is really cool.....
# 297     Temporary Apple Store being set up for #SXSW.....
# 298     Temporary apple store for #sxsw, line goes aro...
# 299     Temporary Apple store opens @mention 6th &amp;...
# 300     Temporary apple store opens at 5pm at 6th and ...
# 301     Temporary Apple Store will be a block from my ...
# 302     The #sxsw Apple store opens at noon each day a...
# 303                        Base Camp Apple.  #SXSW {link}
# 304         iPad news apps 'so last year' at #SXSW {link}
# 305     10 iPhone Apps youÛªll Probably Need and Use ...
# 306     Now there are 150 million mobile google maps u...
# 307     The lines are already forming at Apple's pop-u...
# 308     And a few are Android too RT @mention 10 New M...
# 309     #Sxsw You are attending SXSW? report what you ...
# 310     iPad apps are just like software development i...
# 311     My tweets are stalled. Data sluggish. Come on ...
# 312     Those who are tweeting that Google is coming o...
# 313     ÛÏ@mention Are you Stupid? Find it out at the...
# 314     Slate see as much traffic to mobile safari as ...
# 315     Unloading at #apple store corner of 6th and co...
# 316     Great day at #SXSW -BUT jaloux of @mention &am...
# 317     I arrived at #sxsw and my @mention issue hasn'...
# 318     I will be at #sxsw for Screenburn @mention lau...
# 319     If anyone at #sxsw wants to see a demo of PicC...
# 320     If I were at #SXSW I could spend it all at the...
# 321     If you're at #SXSW : meet us at Fado. We will ...
# 322     If you're at #SXSW and want an iPad 2, Apple's...
# 323     Overheard at #sxsw &quot;the iPad is a relaxin...
# 324     Overheard at #sxsw interactive: &quot;Arg! I h...
# 325     If you're at #sxsw, meet our author, and a hos...
# 326     ÛÏ@mention at #sxsw: &quot;apple comes up wit...
# 327     For those at #SXSW: Apple sets up 5,000-square...
# 328     Overheard at #SXSW: &quot;Google doesn't launc...
# 329     Nerd bait at #SXSW! Apple set to open popup sh...
# 330     Long line at #sxsw? What Else?  Apple Store {l...
# 331     Last year at #SXSWi everbody was talking about...
# 332     Long line at Apple Pop up store for iPad 2. Gr...
# 333     ÛÏ@mention At Google, 4 people do the work of...
# 334     knackered at home playing with ipad and updati...
# 335     overheard at MDW (and I'll second it) &quot;ha...
# 336     #technews At SXSW, Apple schools the marketing...
# 337     First day at sxsw.  Fun final presentation on ...
# 338     Huge line at the #apple store in #austin - #sx...
# 339     If ur not at the #google #aclu 80's party....u...
# 340      The queue at the apple pop-up store #sxsw {link}
# 341     The queue at the Apple Store in Austin is FOUR...
# 342     Posted up at the DMI House, Intimate Stranger ...
# 343     The woman at the Google talk sounded JUST like...
# 344     I laughed at the iPad until I spent this week ...
# 345     Any #SXSW attendees need a QR code reader for ...
# 346     Hey #SXSW attendees...you should hop in line a...
# 347     is anyone attending to the google &amp; aclu p...
# 348     March 11. Austin, TX. Will people line up at t...
# 349     Landed in Austin. Spotted the Google Places Ad...
# 350     they took away the lego pit but replaced it wi...
# 351     ÛÏ@mention Awesome to meet @mention @mention ...
# 352     .@mention Bad Apple: shows up late, Qs the pro...
# 353     .@mention Bahrain govt turned off Google Earth...
# 354     Trying to balance the power of power needs on ...
# 355     Racing to ballroom D to see @mention Marissa M...
# 356          My iPhone battery at 100%. #winning at #SXSW
# 357     My iPhone battery can't keep up with my tweets...
# 358     will this be another google wave? RT @mention ...
# 359     this will be fun to watch. #ipadmadness RT @me...
# 360     This will be out of control: #Apple set to ope...
# 361     Yeah I'll be there for sure! --&gt;RT @mention...
# 362     Celebrate Beauty of the Web @mention the MSFT ...
# 363     Texas has been amazing I've met so many influe...
# 364     I woke up before my iPhone finished recharging...
# 365     The quiet before the storm at #SXSW - Looking ...
# 366     Companies believing in #NFC Google with the Ne...
# 367     ÛÏ@mention Best thing I've heard this weekend...
# 368     Hope it's better than wave RT @mention Buzz is...
# 369     IPad 2 is better..they have had time to improv...
# 370     Cus!\nIt's between pacman google, singularity ...
# 371     {link} Go beyond Earth Hour this year by shari...
# 431     Attending Designing iPad Interfaces - New Navi...
# 432     Check out Designing for Android at SXSW.\n{lin...
# 433     Check out Designing iPad Interfaces - New Navi...
# 434     Check out Designing iPad Interfaces - New Navi...
# 435     Headed to Designing iPad Interfaces - New Navi...
# 436     Taking in Designing iPad Interfaces - New Navi...
# 437     Adobe has developed an engine to essentially c...
# 438     I'm not a developer, but awesome name for the ...
# 439     Behaviour diff. Lots of phone calls while usin...
# 440     Lovin the digital! @mention band sings into iP...
# 441     Why Barry Diller thinks iPad only content is n...
# 442     Why Barry Diller thinks iPad only content is n...
# 443     We really DO need another big social network r...
# 444     Q2 - What do u think of Google's check in offe...
# 445     In Japan: Docomo introduced mobile apps six ye...
# 446     What time does the #apple store at #sxsw open?...
# 447     At #SXSW? Don't forget to come to the #privacy...
# 448     At #SXSW? Don't forget to come to the #privacy...
# 449     Too bad I don't have a _ button!\nRT @mentio...
# 450     Web Devs: Don't wait in line for iPad 2 at #sx...
# 451     ÛÏ@mention Download 20+ FREE tracks from the ...
# 452     ÛÏ@mention Download 20+ FREE tracks from the ...
# 453     ÛÏ@mention Download 20+ FREE tracks from the ...
# 454     ÛÏ@mention DownloadFREE tracks from the #SXSW...
# 455     guess who drew a bigger crowd at #sxsw: @menti...
# 456     Jeez guys dunno about an Apple pop-up over a G...
# 457     Is anyone else using #hashable to network at #...
# 458     @mention  Enjoy #Sxsw and ride anywhere in Aus...
# 459     @mention  Enjoy #Sxsw and ride anywhere in Aus...
# 460     Before It Even Begins, #Apple #Winning #SXSW {...
# 461     Before It Even Begins, #Apple Wins #SXSW {link...
# 462     Before It Even Begins, #Apple Wins #SXSW {link...
# 463     Before it even begins, #Apple wins #SXSW {link...
# 464     Before It Even Begins, #Apple Wins #SXSW: Over...
# 465     Before It Even Begins, Apple Wins #SXSW - Tech...
# 466        Before It Even Begins, Apple Wins #SXSW {link}
# 467        Before it even begins, Apple wins #SXSW {link}
# 468        Before It Even Begins, Apple Wins #SXSW {link}
# 469     Before It Even Begins, Apple Wins #SXSW {link}...
# 470     Before It Even Begins, Apple Wins #SXSW {link}...
# 471     Before It Even Begins, Apple Wins #SXSW {link}...
# 472     Before It Even Begins, Apple Wins #SXSW {link}...
# 473     Before It Even Begins, Apple WinsåÊ#SxSW, {lin...
# 474     Before It Even Begins, Apple Wins SXSW - TechC...
# 475     Before It Even Begins, Apple Wins SXSW {link} ...
# 476     Before It Even Begins, Apple Wins SXSW {link} ...
# 477     Before It Even Begins, Apple Wins SXSW {link} ...
# 478     Before It Even Begins, Apple WinsåÊSXSW {link}...
# 479     Before It Even Begins, Apple Wins SXSW {link} ...
# 480     Before It Even Begins, Apple WinsåÊSXSW {link}...
# 481     Before It Even Begins, Apple Wins SXSW: {link}...
# 482     Badgeless event! Free Drinks! ÛÏ@mention Head...
# 483     BEST SWAG EVER. Thanks @mention My charging iP...
# 484     Thanks to everyone for making it a great day i...
# 485     Thanks to everyone who came by today. Good luc...
# 486     Timing is everything! iPad 2: Brand Winner at ...
# 666     I will be in Austin this weekend @mention #SXS...
# 667     If you're in Austin today, please join @mentio...
# 668     #sxsw guy in front of me at this panel has an ...
# 669     For those in need of sweet Mac goodness at #SX...
# 670     Currently in route to a Truther Movement music...
# 671     This just in: @mention to release new #socialm...
# 672       NFC to be included on iPhone 5? Maybe.... #sxsw
# 673     The apple influence on ditto: one button login...
# 674     WABI-SABI inspiration lab is looking for a spa...
# 675     Zite, the Intelligent iPad Magazine: {link} &l...
# 676     google is interested in location based tech fo...
# 677     Hmm. Very interesting. RT @mention Wonder if @...
# 678     #TheKills interview now on @mention at #sxsw m...
# 679     Can't get into my first panel today. Line look...
# 680     Tim Soo's invisible instruments are jaw droppi...
# 681     Rockin an iPad 2 from the downtown Apple #SXSW...
# 682     #technews iPad 2 Gets Temporary Apple Store fo...
# 683     AWESOME!! ipad 2 jailbreak!! {link} Grateful D...
# 684     Heard the iPad 2 launch at #sxsw was pretty in...
# 685     New Post: iPad 2 Launches to Huge Lines at App...
# 686     ÛÏ@mention iPad 2 Sold Out, 70% Went to New B...
# 687     Remaining iPad 2 stock at #sxsw Apple store.. ...
# 688     I won the iPad accessories bag! Thanks @mentio...
# 689             The #sxsw iPad app is pure gold. @mention
# 690     Check out iPad Design Headaches (2 Tablets, Ca...
# 691     First up: iPad Design Headaches (2 Tablets, Ca...
# 692     the first iPad didn't even exist here last yea...
# 693     Designing iPad Interfaces - New Navigation Sch...
# 694     Designing iPad interfaces with @mention #UXDes...
# 695     Turn your iPad into a 'physical messaging plat...
# 696     Spin Play iPad launch Party. Hanging with @men...
# 697     shoot, my ipad will not display any search res...
# 698     Pic of my iPad-winning performance: {link} #sx...
# 699     I fear no iphone + #att 3gs slowpoke network d...
# 700     The #SXSW iPhone app is mocking me. Like I hav...
# 701     The #SXSW iPhone app is one of the worst I've ...
# 702     Very cool iphone app just launched at #sxsw Fl...
# 703     Pedicab + iPhone charger would be epic win. #SXSW
# 704     Check out iPhone Developer Meet Up at SXSW.\n{...
# 705     Forgot my iPhone for #sxsw. Android only. Knif...
# 706     &quot;the iPhone is a transient device used in...
# 707     Fret not, iPhone owners. Apple to open tempora...
# 708     Disliking iPhone twitter auto shortening links...
# 709     @mention  iPhone. Clearly. Positively. Happily...
# 710             Clipboard is a carny #ipad #lowtech #sxsw
# 711     .@mention is competing with @mention circles o...
# 712     Flipboard is developing an iPhone version, not...
# 713     Microsoft is going to launch IE9 at #SXSW. Ami...
# 714     my iPhone is overheating. why are there so man...
# 715     So {link} is part of my presentation at #SXSW ...
# 716     #hashable is rocking @mention #SXSW the new &q...
# 717     .@mention is super-friendly w google and isn't...
# 718     GameSalad is the topic of a Dutch podcast! {li...
# 719              Soo where is this Apple store at #SXSW ?
# 720     my sister is throwing the Google sxsw party to...
# 721     ÛÏ@mention is walking around #SXSW while star...
# 722     My iPhone is wilting under the stress of being...
# 723     I believe it - I almost always use Google Maps...
# 724     Of course it does! RT @mention #SXSW Gets Its ...
# 725     Rumor has it that apple putting up pop-up stor...
# 793     Google to Launch Major New Social Network Call...
# 794     Google to Launch Major New Social Network Call...
# 795     Google to Launch Major New Social Network Call...
# 796     Google to Launch Major New Social Network Call...
# 797     Google to Launch Major New Social Network Call...
# 798     Google to Launch Major New Social Network Call...
# 799     Google to launch major new social network call...
# 800     Google to Launch Major New Social Network Call...
# 801     Google to Launch Major New Social Network Call...
# 802     Google to Launch Major New Social Network Call...
# 803     Google to Launch Major New Social Network Call...
# 804     Google to Launch Major New Social Network Call...
# 805     Google to Launch Major New Social Network Call...
# 806     Google to Launch Major New Social Network Call...
# 807     Google to Launch Major New Social Network Call...
# 808     Google to Launch Major New Social Network Call...
# 809     Google to Launch Major New Social Network Call...
# 810     Google to Launch Major New Social Network Call...
# 811     Google to launch Major New Social Network call...
# 812     Google to Launch Major New Social Network Call...
# 813     Google to Launch Major New Social Network Call...
# 814     Google to Launch Major New Social Network Call...
# 815     Google to launch new social network at SXSW?  ...
# 816     Google to launch new social network at SXSW? -...
# 817     Google to launch new social network at SXSW? {...
# 818     Google to Launch New Social Network Called Cir...
# 819     Google to launch new social network Circles, l...
# 820     Google to launch new social portal today at #S...
# 821     Google to launch product! Wait, no launch, but...
# 822     Google to launch social network &quot;Circles&...
# 823     Google to launch social network called circles...
# 824     Google to launch social network Google Circles...
# 825     Google to launch their own social network toda...
# 826     Hootsuite launches new Analytics, integrates w...
# 827     Is Google launching a new social network (call...
# ...
# 8818    &quot;SXSW GO is now available iPhone, iPad, A...
# 8819    Dear #SXSW goer... Please look up from your fu...
# 8820    This #SXSW I am grateful for: my bicycle, havi...
# 8821    Photo: How IÛªm spending my Sat night at #SXS...
# 8822    Dear #sxsw iPhone app: you suck again this yea...
# 8823    Wow, #SXSW is so big that Apple is not just at...
# 8824    Woah #SXSW is the buzz word i wake up to!  I h...
# 8825    Free #sxsw Lemonade Stand. iPhone, Android, an...
# 8826    Wonder how many iPads they'll sell there tomor...
# 8827    Wonder how many sold at #SXSW? iPad 2 Sold Out...
# 8828    Free #SXSW music sampler on #itunes. Includes ...
# 8829    HmmÛ_a slew of iPhone app updates (inc. #4sq3...
# 8830    Hey, #SXSW peeps: Go hang out w/ Burners now! ...
# 8831    Geez #sxsw people are eating this up. Another ...
# 8832                   free #sxsw playlist.. enjoy {link}
# 8833    Dear #SXSW re new rule of 'Google b4 twtng..' ...
# 8834    Dang #sxsw rumors RT @mention False Alarm: Goo...
# 8835       Free #SXSW sampler on iTunes {link} #FreeMusic
# 8836    Next #SXSW session - do agencies need to think...
# 8837    I just saw someone filming the #sxsw trade sho...
# 8838    Free #SXSW streams/downloads via new free Wina...
# 8839    I love how the Mac:PC ratio is like 25 to 1 an...
# 8840    Apple know their target audience. Pop-up shop ...
# 8841    Next #SXSW we're heading to is about designing...
# 8842    Don't know what bands to see at #SXSW?  The Fe...
# 8843    Wanna know where the fast cellular signal is a...
# 8844    Wanna know where to get lunch during #sxsw wit...
# 8845    WhatÛªs new with Blogger {link} #blogging #bl...
# 8846    From #SXSW: @mention says @mention playing wit...
# 8847    Free #SXSW: Featured Artists playlist on #iTun...
# 8848    Hipsters w/ oversized earphones pluged into th...
# 8849    We can't wait to give an iPad to someone at #s...
# 8850    Tired of waiting in line @mention stores? Best...
# 8851    @mention Wanna sign up for the beta: {link} #S...
# 8852    Case you wanna stalk me: Google, AustinJS, Roc...
# 8853    Lightbox wants to be Android's new camera, rai...
# 8854    Location wars are heating up in Austin. Google...
# 8855    If there was a popup store in Austin that sold...
# 8856    If there was ever any doubt on the influence o...
# 8857    I wish I was in Austin, if only for the free i...
# 8858    @mention Was just chatting with someone about ...
# 8859    Mashable was there to talk to line takers, man...
# 8860    The line was too long the other day... but I'm...
# 8861    @mention Was your #SXSW iPad talk along the sa...
# 8862    About to watch &quot;Something Ventured&quot;,...
# 8863    The only way you truly understand a material i...
# 8864    #SXSW crowd in Austin swarms for iPad 2 launch...
# 8865    #SXSW crowd in Austin swarms for iPad 2 launch...
# 8866    #SXSW crowd swarms for #iPad2 launch {link} vi...
# 8867    #SXSW crowd swarms for iPad 2 launch  | @menti...
# 8868    #SXSW crowd swarms for iPad 2 launch - {link} ...
# 8869    #SXSW crowd swarms for iPad 2 launch {link} vi...
# 8870    Looking fwd to iPad DJ @mention at our @mentio...
# 8871    SXSW: Crowds for iPad 2 launch - CNN {link} #sxsw
# 8872    @mention we are actually giving away 10 #FREE ...
# 8873    @mention We are in line at the Apple pop-up st...
# 8874    @mention We are working towards Android but it...
# 8875    @mention We can offer an apple and some tinfoi...
# 8876    @mention we were on the right track RT @mentio...
# 8877    Crowley: We're growing up. FourSquare  competi...
# 8878    @mention We're tight w/ Google. Lot of my frie...
# 8879    ReadWriteWeb is reporting Google might launch ...
# 8880    #SXSW I tweeted too fast it appears Google may...
# 8881    I'll be tweeting out #SXSW sessions I'm going ...
# 8882    @mention Welcome! Enjoy #Sxsw and ride anywher...
# 8883    @mention well #SXSW is an iPad commercial ... ...
# 8884    @mention Well I did hear that someone was gonn...
# 8885       @mention well put. totally agree! #apple #sxsw
# 8886    @mention Well, I hope you make it easier for m...
# 8887    Wish you went to #sxsw? We got you covered! Da...
# 8888    I wish I were at #sxsw. I wish I had an iPad 2...
# 8889    Ummmm...awesome? Party? RT djroe Apple store d...
# 8890    This is awesome....   How I got an iPad 2 duri...
# 8891    @mention What are the chances they'll have a b...
# 8892    @mention what did you think of google presenta...
# 8893    @mention What is the most optimal way to acces...
# 8894    @mention what size did you get? Did you got th...
# 8895    @mention What, *the* Guy Kawasaki? Former Appl...
# 8896    @mention What's going on at #sxsw today? Share...
# 8897    FRIENDS: What's going on at #sxsw today? Share...
# 8898    @mention What's the wait time lookin like? The...
# 8899    Deciding when to release a product is an art, ...
# 8900    @mention Where is the temp #apple store at #sxsw?
# 8901    @mention where's the apple #sxsw set-up? Can a...
# 8902    @mention Which is to say iPad is going to be u...
# 8903    Debating which laptop to take to #SXSW when I'...
# 8904                   Black or white iPad?  #sxsw #iPad2
# 8905    We see a WHITE IPAD 2! RT @mention Now you kno...
# 8906    @mention Who said you won't be able to get the...
# 8907    Curious. Why was Google surprised by the usage...
# 8908    @mention Why? Google #SXSW Austin, Texas 2011!...
# 8909    Post: SXSWi 2011. Day 1. #BPM @mention #SXSW {...
# 8910    From #SXSWi... RT @mention Google says the fut...
# 8911    Livetapp will be raffling off an iPad 2 at #SX...
# 8912    @mention will we get the #android update by/fo...
# 8913    Time to switch to @mention on my iPhone so I c...
# 8914    Chilling with @mention at the big hair station...
# 8915    Partying with #Android and @mention #sxsw @men...
# 8916    At #SXSW with a thirsty gadget? Using @mention...
# 8917    At #sxsw with an iPhone? Use FREE iSpyArt App ...
# 8918    Jonathan with Zaggle showed us a cool free tex...
# 8919    Current Twitter feed: devastation in Japan, pa...
# 8920    Get the OWLE Bubo for iPhone with a $20 off co...
# 8921    Anyone down at #SXSW wanna bring me back a Win...
# 8922    Walkin down the street @mention is navigating ...
# 8923    Google ARwords, ARsense anyone? #ARSXSW #SXSW ...
# 8924    @mention worked with @mention to create open-s...
# 8925    umm that would be @mention ÛÏ@mention I keep ...
# 8926    #YourMom would prob have more to say about des...
# 8927    @mention wow - a gold's gym underneath an Appl...
# 8928    @mention wow! You just came up in my Google re...
# 8929    Clearly #wp7dev won the mobile smackdown v iPh...
# 8930    #iPad #news #apps not popular with the #kids. ...
# 8931    Video shows a guy hacking Times Sq billboards ...
# 8932    Z6: No News is Good News {link} [codes valid: ...
# 8933    #Socialnews RT @mention Facebook can breathe a...
# 8934    Apple knows what game they're in at #sxsw. Bri...
# 8935    Apple knows where the influencers will be: App...
# 8936    CLIENT NEWS! @mention Releases &quot;Dope Melo...
# 8937    which browser do u prefer? Internet Explorer 9...
# 8938    Join leNewz fo free donuts and massage at #SXS...
# 8939    {link} thx to @mention and @mention for this p...
# 8940    Leaving excellent panel from @mention on Writi...
# 8941    Getting excited to present *Spark at Team andr...
# 8942    #SXSW ##UXDes Check out Designing iPad Interfa...
# 8943    Hmmm...Taxi Magic on iPhone does not appear to...
# 8944    Great 3D XML visualization of skiers using Goo...
# 8945    FestivalExplorer iPhone App Finally Solves SXS...
# 8946    Preso l'express pass per The City Dark e Road ...
# 8947    #Apple #SXSW &quot;pop-up&quot; store is smart...
# 8948          At the #SXSW #Android meet up in the Hilton
# 8949            At the #SXSW #apple store in #ATX  {link}
# 8950    Before #sxsw even starts, Apple has captured t...
# 8951    New at #sxsw film this year: folks sitting in ...
# 8952              {link} #sxsw Google going Social again?
# 8953    At the #sxsw Google Blogger/Sketchup party wit...
# 8954    Austin #SXSW iPad 2 line now 1.75 blocks long ...
# 8955    #cloud #sxsw keep personal stuff on corp iPad ...
# 8956    Follow #SXSW on My Taptu:&quot;Apple iPad 2 li...
# 8957    Not at #sxsw or in line for an #iPad I feel li...
# 8958    iPAD / #SXSW PEOPLE: @mention brilliant Spider...
# 8959    iPad 2 #sxsw pop-up store (@mention Apple Stor...
# 8960    #japan #SXSW put you collective entrepreneuria...
# 8961    PDX to #sxsw tomorrow. Drop me a note if you'l...
# 8962    I love #sxsw. I opened the @mention app on my ...
# 9023    Apparently, if you Google &quot;ad preferences...
# 9024    by the way, we're looking for a spanish-speaki...
# 9025    Absolutely!  RT @mention Timely good schtuff f...
# 9026    True story! RT @mention I just rated Amy's Ice...
# 9027    Good job y'all!  RT @mention Yes! Gowalla wins...
# 9028    &quot;They're in line for some ipad thing&quot...
# 9029    [TOP STORY] At #SXSW, Apple schools the market...
# 9030    @mention yay :) thank you! what do you do? #pu...
# 9031      ... or maybe not: {link} #google #circles #sxsw
# 9032    @mention yeah, we have @mention , Google has n...
# 9033    @mention yep! I can't believe they set up a po...
# 9034    Marisa Meyer is showing yelp, aka google hotpo...
# 9035    @mention Yes, I picked up the ipad 2 at #SXSW....
# 9036    @mention Yes, that's why I favorited it! I wan...
# 9037    @mention Yes, the Google presentation was not ...
# 9038    Mobile mayhem! RT @mention Hoot! New Blog post...
# 9039    Who is flying to #SXSW and wants some @mention...
# 9040    Google trying to fill void for local informati...
# 9041    #SXSW #beyondwc Analytics 101: Google Analytic...
# 9042    dear everyone coming to #SXSW, a friendly remi...
# 9043    Hey is anyone doing #sxsw signing up for the g...
# 9044    Look everyone! Zomg @mention got an iPad 2 on ...
# 9045    @mention you are my favorite-- thanks for comi...
# 9046    you know you are on the plane to #SXSW when u ...
# 9047    Those of you at #SXSW I need the details on Go...
# 9048    @mention You bet man! Kindle and Apple for sur...
# 9049    @mention you can buy my used iPad and I'll pic...
# 9050    @mention you can check out {link} for other #S...
# 9051    @mention You can get an iPad 1 for under $350 ...
# 9052    @mention You could buy a new iPad 2 tmrw at th...
# 9053    @mention you could win a #sony Xperia play bef...
# 9054    Guys, if you ever plan on attending #SXSW, you...
# 9055     @mention you give away that iPad yet.... ? #sxsw
# 9056    @mention you going to #Google announcement @me...
# 9057    @mention You guys should do this &amp; give me...
# 9058    &quot;Do you know what Apple is really good at...
# 9059    @mention you know...they sell apple products a...
# 9060    @mention you might also appreciate new iPhone ...
# 9061    @mention You realize I'm still padless? I just...
# 9062    @mention you should find @mention or...you can...
# 9063    @mention You should get the iPad 2  to save yo...
# 9064    @mention you should see the line here at #SXSW...
# 9065    Soooo do you think Apple will have a mobile st...
# 9066    How much you want to bet Apple is disproportio...
# 9067    &quot;If you were able to afford to attend  #s...
# 9068    @mention you'll be at the google party tonight...
# 9069    @mention You're not sure how many you ate? Tha...
# 9070    You know you've made it to #sxsw when you see ...
# 9071    what are your essentials for #SxSW?  Mine? poc...
# 9072    @mention your iPhone 4 cases are Rad and Ready...
# 9073    At #SXSW your iphone charger is your best friend.
# 9074    At &quot;Your Mom Has an iPad: Designing for B...
# 9075    At &quot;Your Mom Has an iPad&quot; session #y...
# 9076    At &quot;Your Mom Has an iPad&quot; session at...
# 9077    @mention your PR guy just convinced me to swit...
# 9078    Cue the hype RT @mention We interrupt your reg...
# 9079    &quot;papyrus...sort of like the ipad&quot; - ...
# 9080    Diller says Google TV &quot;might be run over ...
# 9081    Google says reports about launch of Circles so...
# 9082    #Apple guys screaming and running by line to o...
# 9083    Google says the future is all around you! (ie,...
# 9084    Google says the future is location, location, ...
# 9085    I've always used Camera+ for my iPhone b/c it ...
# 9086    Google says: want to give a lightning talk to ...
# 9087    @mention Yup, but I don't have a third app yet...
# 9088                        Ipad everywhere. #SXSW {link}
# 9089    Wave, buzz... RT @mention We interrupt your re...
# 9090    Google's Zeiger, a physician never reported po...
# 9091    Some Verizon iPhone customers complained their...
# 9092    Ï¡Ïàü_ÊÎÒ£Áââ_£â_ÛâRT @...
# Name: tweet_original, dtype: object

# %%
df_full = df.merge(df_tweet, left_index=True, right_index=True)

# %%
import nltk
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
import string, re
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
## setting stopwords and punctuations
stop_words=stopwords.words("english")
stop_words += list(string.punctuation)
stop_words += ['...','u','w','2',"i'm",'via',"we're",'6','3','hey']
# print(stop_words)
sw_set = set(stop_words)
# sw_set

# %%
def process_tweet(tweet):
    tokenizer = RegexpTokenizer(r"(iPad\s2|[a-zA-Z0-9-]+'?\w+)")

    tokens = tokenizer.tokenize(tweet)
    sw_removed = [token.lower().replace(" ","") for token in tokens if token.lower() not in sw_set]
    return sw_removed

# %%
#I want to get word counts for lots of subsets of the data (by product and valence)
#input should be the original df['tweet'] already subset
#it's df_full['tweet_original']
def word_count_func(data):
    #using the process_tweet function to tokenize, lower and remove stopwords
    process_data = list(map(process_tweet, data))
    
    #lemmatizing words
    from nltk.stem import WordNetLemmatizer 
      
    #instantiating
    lemmatizer = WordNetLemmatizer() 

    #process_data is a list of lists - here looping over the lists and then the words in the list
    lemmatizer_tweets=[]
    for l in process_data:
        new_row = []
        for w in l:
            new_row.append(lemmatizer.lemmatize(w))
        lemmatizer_tweets.append(new_row)   
    
    #This is more descriptive info - calculating the unique vocab of the subset
    overall_lem_vocab = set()
    for tweet in lemmatizer_tweets:
        overall_lem_vocab.update(tweet)
    print(f'Overall vocab of subset: {len(overall_lem_vocab)}')

    #Flattening (going from a list of lists to one single list) the lemmatized tweets for freq
    flat_lemmatizer_tweets = [item for sublist in lemmatizer_tweets for item in sublist]
    
    #applying nltk freqdist function to the flat list
    lem_freq = FreqDist(flat_lemmatizer_tweets)
    print('30 most common words in subset:')
    print(lem_freq.most_common(30))
    
    #returning normalized word freq because there are different N's
    total_words = sum(lem_freq.values())
    top_30 = lem_freq.most_common(30)
    print("Word \t\t Normalized Frequency")
    print()
    for word in top_30:
        normalized_frequency = word[1]/total_words
        print("{} \t\t {:.4}".format(word[0], normalized_frequency))
        
    #Creating word clouds - input is a dict with key word value num of occurences 
    word_dict = dict(top_30)
    from wordcloud import WordCloud
    wordcloud = WordCloud(colormap='Spectral').generate_from_frequencies(word_dict)
    
    # Display the generated image w/ matplotlib:

    plt.figure(figsize=(10,10), facecolor='k')
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.tight_layout(pad=0)
    plt.show()

# %%
data1 = df_full['tweet_original']
word_count_func(data1)
# Out:
# Overall vocab of subset: 9225
# 30 most common words in subset:
# [('sxsw', 9601), ('mention', 7124), ('link', 4323), ('rt', 2968), ('google', 2465), ('apple', 2230), ('quot', 1696), ('ipad', 1576), ('iphone', 1571), ('store', 1519), ('ipad2', 1370), ('new', 1090), ('austin', 958), ('amp', 836), ('app', 821), ('launch', 691), ('circle', 691), ('social', 649), ('android', 593), ('today', 574), ('network', 474), ('get', 455), ('line', 444), ('pop-up', 422), ('party', 401), ('free', 387), ('called', 361), ('mobile', 346), ('sxswi', 342), ('time', 305)]
# Word 		 Normalized Frequency
#
# sxsw 		 0.08633
# mention 		 0.06406
# link 		 0.03887
# rt 		 0.02669
# google 		 0.02217
# apple 		 0.02005
# quot 		 0.01525
# ipad 		 0.01417
# iphone 		 0.01413
# store 		 0.01366
# ipad2 		 0.01232
# new 		 0.009802
# austin 		 0.008615
# amp 		 0.007518
# app 		 0.007383
# launch 		 0.006214
# circle 		 0.006214
# social 		 0.005836
# android 		 0.005332
# today 		 0.005162
# network 		 0.004262
# get 		 0.004091
# line 		 0.003993
# pop-up 		 0.003795
# party 		 0.003606
# free 		 0.00348
# called 		 0.003246
# mobile 		 0.003111
# sxswi 		 0.003075
# time 		 0.002743

# %% [markdown]
# ## Word frequencies by Product and Valence <a id="Word-freq-by-prod"></a>
# ##### [(back to top)](#EDA)

# %%
df_full['product_agg'].value_counts()
# Out:
# Unknown    5801
# Apple      2409
# Google      723
# Android     158
# Name: product_agg, dtype: int64

# %%
data_apple = df_full.loc[df_full['product_agg'] == 'Apple','tweet_original']
word_count_func(data_apple)
# Out:
# Overall vocab of subset: 4680
# 30 most common words in subset:
# [('sxsw', 2551), ('mention', 1756), ('link', 1076), ('rt', 684), ('apple', 664), ('google', 499), ('ipad', 482), ('iphone', 457), ('store', 435), ('ipad2', 420), ('quot', 413), ('austin', 269), ('app', 251), ('new', 230), ('amp', 192), ('android', 156), ('line', 131), ('get', 127), ('pop-up', 125), ('launch', 117), ('free', 113), ('today', 113), ('social', 102), ('party', 100), ('like', 98), ('circle', 97), ('time', 88), ('win', 88), ('one', 87), ('temporary', 79)]
# Word 		 Normalized Frequency
#
# sxsw 		 0.08838
# mention 		 0.06084
# link 		 0.03728
# rt 		 0.0237
# apple 		 0.023
# google 		 0.01729
# ipad 		 0.0167
# iphone 		 0.01583
# store 		 0.01507
# ipad2 		 0.01455
# quot 		 0.01431
# austin 		 0.00932
# app 		 0.008696
# new 		 0.007968
# amp 		 0.006652
# android 		 0.005405
# line 		 0.004539
# get 		 0.0044
# pop-up 		 0.004331
# launch 		 0.004053
# free 		 0.003915
# today 		 0.003915
# social 		 0.003534
# party 		 0.003465
# like 		 0.003395
# circle 		 0.003361
# time 		 0.003049
# win 		 0.003049
# one 		 0.003014
# temporary 		 0.002737

# %%
data_android = df_full.loc[df_full['product_agg'] == 'Android','tweet_original']
word_count_func(data_android)
# Out:
# Overall vocab of subset: 864
# 30 most common words in subset:
# [('sxsw', 166), ('mention', 126), ('link', 67), ('rt', 40), ('google', 38), ('iphone', 34), ('apple', 33), ('android', 31), ('app', 30), ('ipad', 27), ('quot', 25), ('store', 19), ('new', 18), ('austin', 16), ('amp', 15), ('today', 12), ('ipad2', 10), ('party', 9), ('pop-up', 9), ('get', 8), ('circle', 8), ('people', 7), ('free', 7), ('launch', 7), ('check', 7), ('awesome', 6), ('apps', 6), ('think', 6), ('love', 6), ('team', 6)]
# Word 		 Normalized Frequency
#
# sxsw 		 0.08605
# mention 		 0.06532
# link 		 0.03473
# rt 		 0.02074
# google 		 0.0197
# iphone 		 0.01763
# apple 		 0.01711
# android 		 0.01607
# app 		 0.01555
# ipad 		 0.014
# quot 		 0.01296
# store 		 0.00985
# new 		 0.009331
# austin 		 0.008294
# amp 		 0.007776
# today 		 0.006221
# ipad2 		 0.005184
# party 		 0.004666
# pop-up 		 0.004666
# get 		 0.004147
# circle 		 0.004147
# people 		 0.003629
# free 		 0.003629
# launch 		 0.003629
# check 		 0.003629
# awesome 		 0.00311
# apps 		 0.00311
# think 		 0.00311
# love 		 0.00311
# team 		 0.00311

# %%
data_google = df_full.loc[df_full['product_agg'] == 'Google','tweet_original']
word_count_func(data_google)
# Out:
# Overall vocab of subset: 2269
# 30 most common words in subset:
# [('sxsw', 749), ('mention', 536), ('google', 334), ('link', 330), ('rt', 230), ('quot', 163), ('apple', 126), ('ipad', 117), ('new', 106), ('iphone', 100), ('store', 90), ('circle', 88), ('social', 82), ('amp', 81), ('launch', 71), ('ipad2', 68), ('network', 65), ('austin', 63), ('app', 59), ('today', 55), ('mobile', 50), ('called', 49), ('map', 46), ('major', 45), ('party', 43), ('mayer', 39), ('marissa', 35), ('line', 35), ('get', 32), ('sxswi', 30)]
# Word 		 Normalized Frequency
#
# sxsw 		 0.08331
# mention 		 0.05962
# google 		 0.03715
# link 		 0.0367
# rt 		 0.02558
# quot 		 0.01813
# apple 		 0.01401
# ipad 		 0.01301
# new 		 0.01179
# iphone 		 0.01112
# store 		 0.01001
# circle 		 0.009788
# social 		 0.00912
# amp 		 0.009009
# launch 		 0.007897
# ipad2 		 0.007563
# network 		 0.007229
# austin 		 0.007007
# app 		 0.006562
# today 		 0.006117
# mobile 		 0.005561
# called 		 0.00545
# map 		 0.005116
# major 		 0.005005
# party 		 0.004783
# mayer 		 0.004338
# marissa 		 0.003893
# line 		 0.003893
# get 		 0.003559
# sxswi 		 0.003337

# %%
data_unknown = df_full.loc[df_full['product_agg'] == 'Unknown','tweet_original']
word_count_func(data_unknown)
# Out:
# Overall vocab of subset: 7460
# 30 most common words in subset:
# [('sxsw', 6135), ('mention', 4706), ('link', 2850), ('rt', 2014), ('google', 1594), ('apple', 1407), ('quot', 1095), ('iphone', 980), ('store', 975), ('ipad', 950), ('ipad2', 872), ('new', 736), ('austin', 610), ('amp', 548), ('circle', 498), ('launch', 496), ('app', 481), ('social', 460), ('today', 394), ('android', 381), ('network', 340), ('get', 288), ('line', 273), ('pop-up', 270), ('called', 259), ('free', 250), ('party', 249), ('sxswi', 232), ('mobile', 225), ('major', 216)]
# Word 		 Normalized Frequency
#
# sxsw 		 0.0859
# mention 		 0.06589
# link 		 0.0399
# rt 		 0.0282
# google 		 0.02232
# apple 		 0.0197
# quot 		 0.01533
# iphone 		 0.01372
# store 		 0.01365
# ipad 		 0.0133
# ipad2 		 0.01221
# new 		 0.0103
# austin 		 0.008541
# amp 		 0.007673
# circle 		 0.006973
# launch 		 0.006945
# app 		 0.006735
# social 		 0.006441
# today 		 0.005516
# android 		 0.005334
# network 		 0.00476
# get 		 0.004032
# line 		 0.003822
# pop-up 		 0.00378
# called 		 0.003626
# free 		 0.0035
# party 		 0.003486
# sxswi 		 0.003248
# mobile 		 0.00315
# major 		 0.003024

# %% [markdown]
# ## Summary of output:
# At a bit of a loss how to interpret this. SXSW was the most frequent for all products - obviously tweets were from SXSW.  But there is no (eyeball level) specificity in terms.

# %% [markdown]
# ### Assessing word frequency for valence

# %%
df_full.columns
# Out:
# Index(['tweet', 'product_', 'emotion', 'lemmatizer_tweets',
#        'textblob_polarity', 'textblob_subjectivity', 'vs_neg', 'vs_neu',
#        'vs_pos', 'vs_compound', 'product_agg', 'tweet_original'],
#       dtype='object')

# %%
df_full['vs_neg'].describe()
# Out:
# count    9091.000000
# mean        0.033712
# std         0.078833
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.634000
# Name: vs_neg, dtype: float64

# %%
#arbitrarily chose vs_neg score of greater than or equal to 0.50 - corresponds to proportion
#of the tweet that is negative 
data_neg = df_full.loc[df_full['vs_neg'] >= 0.5,'tweet_original']
word_count_func(data_neg)
# Out:
# Overall vocab of subset: 38
# 30 most common words in subset:
# [('sxsw', 4), ('quot', 2), ('best', 2), ('viewed', 2), ('explorer', 2), ('mayer', 1), ('showcasing', 1), ('google', 1), ('place', 1), ('hotpot', 1), ('restaurants-rating', 1), ('tool', 1), ('hello', 1), ('mobile', 1), ('advertising', 1), ('check-in', 1), ('push', 1), ('experimenting', 1), ('tinkering', 1), ('like', 1), ('ninety', 1), ('ipad', 1), ('new', 1), ('internet', 1), ('festival', 1), ('austin', 1), ('edition', 1), ('help', 1), ('keep', 1), ('track', 1)]
# Word 		 Normalized Frequency
#
# sxsw 		 0.08889
# quot 		 0.04444
# best 		 0.04444
# viewed 		 0.04444
# explorer 		 0.04444
# mayer 		 0.02222
# showcasing 		 0.02222
# google 		 0.02222
# place 		 0.02222
# hotpot 		 0.02222
# restaurants-rating 		 0.02222
# tool 		 0.02222
# hello 		 0.02222
# mobile 		 0.02222
# advertising 		 0.02222
# check-in 		 0.02222
# push 		 0.02222
# experimenting 		 0.02222
# tinkering 		 0.02222
# like 		 0.02222
# ninety 		 0.02222
# ipad 		 0.02222
# new 		 0.02222
# internet 		 0.02222
# festival 		 0.02222
# austin 		 0.02222
# edition 		 0.02222
# help 		 0.02222
# keep 		 0.02222
# track 		 0.02222

# %%
#0.5 seems really small
data_neg2 = df_full.loc[df_full['vs_neg'] >= 0.4,'tweet_original']
word_count_func(data_neg2)
# Out:
# Overall vocab of subset: 233
# 30 most common words in subset:
# [('sxsw', 34), ('mention', 16), ('link', 13), ('google', 7), ('iphone', 6), ('quot', 6), ('make', 4), ('new', 4), ('get', 4), ('ipad', 4), ('tool', 4), ('check', 4), ('app', 4), ('apple', 3), ('free', 3), ('itunes', 3), ('amp', 3), ('best', 3), ('good', 3), ('rt', 3), ('want', 2), ('hundred', 2), ('austin', 2), ('team', 2), ('day', 2), ('help', 2), ('meet', 2), ('map', 2), ('mobile', 2), ('software', 2)]
# Word 		 Normalized Frequency
#
# sxsw 		 0.09315
# mention 		 0.04384
# link 		 0.03562
# google 		 0.01918
# iphone 		 0.01644
# quot 		 0.01644
# make 		 0.01096
# new 		 0.01096
# get 		 0.01096
# ipad 		 0.01096
# tool 		 0.01096
# check 		 0.01096
# app 		 0.01096
# apple 		 0.008219
# free 		 0.008219
# itunes 		 0.008219
# amp 		 0.008219
# best 		 0.008219
# good 		 0.008219
# rt 		 0.008219
# want 		 0.005479
# hundred 		 0.005479
# austin 		 0.005479
# team 		 0.005479
# day 		 0.005479
# help 		 0.005479
# meet 		 0.005479
# map 		 0.005479
# mobile 		 0.005479
# software 		 0.005479

# %%
data_pos = df_full.loc[df_full['vs_pos'] >= 0.5,'tweet_original']
word_count_func(data_pos)
# Out:
# Overall vocab of subset: 746
# 30 most common words in subset:
# [('sxsw', 149), ('mention', 100), ('link', 77), ('rt', 49), ('google', 35), ('apple', 34), ('ipad2', 27), ('iphone', 23), ('store', 22), ('quot', 22), ('ipad', 19), ('free', 14), ('austin', 14), ('party', 13), ('amp', 13), ('new', 12), ('android', 11), ('circle', 10), ('social', 9), ('app', 9), ('win', 9), ('launch', 8), ('line', 8), ('get', 7), ('one', 7), ('com', 7), ('day', 6), ('today', 6), ('talk', 6), ('pop-up', 6)]
# Word 		 Normalized Frequency
#
# sxsw 		 0.08653
# mention 		 0.05807
# link 		 0.04472
# rt 		 0.02846
# google 		 0.02033
# apple 		 0.01974
# ipad2 		 0.01568
# iphone 		 0.01336
# store 		 0.01278
# quot 		 0.01278
# ipad 		 0.01103
# free 		 0.00813
# austin 		 0.00813
# party 		 0.007549
# amp 		 0.007549
# new 		 0.006969
# android 		 0.006388
# circle 		 0.005807
# social 		 0.005226
# app 		 0.005226
# win 		 0.005226
# launch 		 0.004646
# line 		 0.004646
# get 		 0.004065
# one 		 0.004065
# com 		 0.004065
# day 		 0.003484
# today 		 0.003484
# talk 		 0.003484
# pop-up 		 0.003484

# %%
data_pos2 = df_full.loc[df_full['vs_pos'] >= 0.6 ,'tweet_original']
word_count_func(data_pos2)
# Out:
# Overall vocab of subset: 220
# 30 most common words in subset:
# [('sxsw', 37), ('mention', 32), ('link', 23), ('rt', 13), ('apple', 11), ('iphone', 6), ('store', 6), ('ipad2', 6), ('google', 5), ('austin', 4), ('launch', 4), ('app', 4), ('line', 4), ('today', 3), ('tomorrow', 3), ("i've", 3), ('ipad', 3), ('yes', 3), ('new', 3), ('android', 3), ('party', 3), ('thanks', 2), ('great', 2), ('see', 2), ('talk', 2), ('meeting', 2), ('11', 2), ('congrats', 2), ('awesome', 2), ('experience', 2)]
# Word 		 Normalized Frequency
#
# sxsw 		 0.09113
# mention 		 0.07882
# link 		 0.05665
# rt 		 0.03202
# apple 		 0.02709
# iphone 		 0.01478
# store 		 0.01478
# ipad2 		 0.01478
# google 		 0.01232
# austin 		 0.009852
# launch 		 0.009852
# app 		 0.009852
# line 		 0.009852
# today 		 0.007389
# tomorrow 		 0.007389
# i've 		 0.007389
# ipad 		 0.007389
# yes 		 0.007389
# new 		 0.007389
# android 		 0.007389
# party 		 0.007389
# thanks 		 0.004926
# great 		 0.004926
# see 		 0.004926
# talk 		 0.004926
# meeting 		 0.004926
# 11 		 0.004926
# congrats 		 0.004926
# awesome 		 0.004926
# experience 		 0.004926

# %% [markdown]
# ## Summary
# More info with the valence categries:
# * Overall - assuming SXSW and mention were used in all tweets about the festival
# * negative >= 0.5.  Looks like people were complaining about hotspots/internet, check-in, tool/mobile(maybe the mobile site or another tool), restaurants, experimenting/tinkering (I think they wanted to play with the toys and didn't get to).  "viewed, explorer and mayer" were highly frequent.  Unsure what these refer to.
# * positive >= 0.6.  'Link' and 'rt' are high - assuming people are linking to or retweeting new products they like.  I would infer general excitment for the various products from "being in 'line' 'today'/'tomorrow' 'launch' and the product names". And general thanks/congrats for "seeing/meeting" someone potentially at a 'party'

# %% [markdown]
# ## Creating termite plot overall and by products and valence<a id="termite"></a>
# ##### [(back to top)](#EDA)

# %%
def termite_word_count_func(data):
    #using the process_tweet function to tokenize, lower and remove stopwords
    process_data = list(map(process_tweet, data))
    
    #lemmatizing words
    from nltk.stem import WordNetLemmatizer 
      
    #instantiating
    lemmatizer = WordNetLemmatizer() 

    #process_data is a list of lists - here looping over the lists and then the words in the list
    lemmatizer_tweets=[]
    for l in process_data:
        new_row = []
        for w in l:
            new_row.append(lemmatizer.lemmatize(w))
        lemmatizer_tweets.append(new_row)   
    
    #This is more descriptive info - calculating the unique vocab of the subset
    overall_lem_vocab = set()
    for tweet in lemmatizer_tweets:
        overall_lem_vocab.update(tweet)
#     print(f'Overall vocab of subset: {len(overall_lem_vocab)}')

    #Flattening (going from a list of lists to one single list) the lemmatized tweets for freq
    flat_lemmatizer_tweets = [item for sublist in lemmatizer_tweets for item in sublist]
    
    #applying nltk freqdist function to the flat list
    lem_freq = FreqDist(flat_lemmatizer_tweets)
#     print('30 most common words in subset:')
#     print(lem_freq.most_common(30))
    
    #returning normalized word freq because there are different N's
    total_words = sum(lem_freq.values())
    top_30 = lem_freq.most_common(30)
#     print("Word \t\t Normalized Frequency")
#     print()
    top_30_words = []
    for word in top_30:
        normalized_frequency = word[1]/total_words
        top_30_words.append((word[0], normalized_frequency))
    return top_30_words

# %%
#convert tuple to dictionary
def Convert(tup):
    di = {}
    for a, b in tup:
        di.setdefault(a, []).append(b)
    return di

# %% [markdown]
# ### Create tuples for overall, apple, google, android, pos and neg labels

# %%
#Getting tuple of normalized word frequency on full dataste
data1 = df_full['tweet_original']
main_tuple = termite_word_count_func(data1)

# %%
data_apple = df_full.loc[df_full['product_agg']=='Apple','tweet_original']
apple_tuple = termite_word_count_func(data_apple)

# %%
data_google = df_full.loc[df_full['product_agg']=='Google','tweet_original']
google_tuple = termite_word_count_func(data_google)

# %%
data_android = df_full.loc[df_full['product_agg']=='Android','tweet_original']
android_tuple = termite_word_count_func(data_android)

# %%
data_neg = df_full.loc[df_full['emotion']==0,'tweet_original']
neg_tuple = termite_word_count_func(data_neg)

# %%
data_pos = df_full.loc[df_full['emotion']==1,'tweet_original']
pos_tuple = termite_word_count_func(data_pos)

# %%
tuples_list = [main_tuple,apple_tuple,google_tuple,android_tuple,neg_tuple,pos_tuple]

# %%
#Converting tuple to dictionary
dict_list = []
for tuple_ in tuples_list:
    x = Convert(tuple_)
    dict_list.append(x)
# main_tuple_dict = Convert(main_tuple)
# apple_tuple_dict = Convert(apple_tuple)
# google_tuple_dict = Convert(google_tuple)
# android_tuple_dict = Convert(android_tuple)
# negative_tuple_dict = Convert(neg_tuple)
# positive_tuple_dict = Convert(pos_tuple)
# dict_list.append(main_tuple_dict)

# %%
dict_list[0]['sxsw'][0]
# Out:
# 0.08633449333225426

# %%
overall_new = []
for i in range(len(dict_list)):
    new_dict_list = {}
    for key, value in dict_list[i].items():
        new_dict_list[key] = value[0]
    overall_new.append(new_dict_list)
overall_new
# Out:
# [{'sxsw': 0.08633449333225426,
#   'mention': 0.06406071560243509,
#   'link': 0.03887345221074213,
#   'rt': 0.026688967421115577,
#   'google': 0.02216587085345347,
#   'apple': 0.02005269452462525,
#   'quot': 0.015250838526351758,
#   'ipad': 0.014171769762694795,
#   'iphone': 0.014126808564209087,
#   'store': 0.013659212099957737,
#   'ipad2': 0.012319368385083672,
#   'new': 0.00980154126988409,
#   'austin': 0.00861456562986143,
#   'amp': 0.0075175123868101825,
#   'app': 0.0073826287913530625,
#   'launch': 0.0062136376307246844,
#   'circle': 0.0062136376307246844,
#   'social': 0.005835963563444747,
#   'android': 0.0053323981404048305,
#   'today': 0.005161545586159145,
#   'network': 0.004262321616445008,
#   'get': 0.004091469062199322,
#   'line': 0.003992554425530767,
#   'pop-up': 0.003794725152193657,
#   'party': 0.0036058881185536884,
#   'free': 0.0034799967627937092,
#   'called': 0.0032461985306680334,
#   'mobile': 0.003111314935210913,
#   'sxswi': 0.0030753459764223477,
#   'time': 0.002742633107628117},
#  {'sxsw': 0.0883799889135255,
#   'mention': 0.0608370288248337,
#   'link': 0.037278270509977826,
#   'rt': 0.023697339246119734,
#   'apple': 0.023004434589800442,
#   'google': 0.017287971175166297,
#   'ipad': 0.016699002217294902,
#   'iphone': 0.015832871396895785,
#   'store': 0.015070676274944567,
#   'ipad2': 0.0145509977827051,
#   'quot': 0.014308481152993349,
#   'austin': 0.009319567627494457,
#   'app': 0.008695953436807095,
#   'new': 0.00796840354767184,
#   'amp': 0.0066518847006651885,
#   'android': 0.0054046563192904655,
#   'line': 0.0045385254988913526,
#   'get': 0.004399944567627495,
#   'pop-up': 0.004330654101995565,
#   'launch': 0.004053492239467849,
#   'free': 0.003914911308203991,
#   'today': 0.003914911308203991,
#   'social': 0.0035338137472283814,
#   'party': 0.0034645232815964525,
#   'like': 0.003395232815964523,
#   'circle': 0.003360587583148559,
#   'time': 0.003048780487804878,
#   'win': 0.003048780487804878,
#   'one': 0.0030141352549889135,
#   'temporary': 0.0027369733924611974},
#  {'sxsw': 0.0833055277499722,
#   'mention': 0.059615170726281835,
#   'google': 0.03714825937048159,
#   'link': 0.03670337003670337,
#   'rt': 0.025581136692247805,
#   'quot': 0.018129240351462572,
#   'apple': 0.014014014014014014,
#   'ipad': 0.013013013013013013,
#   'new': 0.011789567345122902,
#   'iphone': 0.011122233344455567,
#   'store': 0.01001001001001001,
#   'circle': 0.009787565343120898,
#   'social': 0.009120231342453565,
#   'amp': 0.009009009009009009,
#   'launch': 0.007896785674563452,
#   'ipad2': 0.0075631186742297855,
#   'network': 0.007229451673896118,
#   'austin': 0.007007007007007007,
#   'app': 0.0065621176732287845,
#   'today': 0.006117228339450562,
#   'mobile': 0.0055611166722277835,
#   'called': 0.005449894338783227,
#   'map': 0.005116227338449561,
#   'major': 0.005005005005005005,
#   'party': 0.004782560338115894,
#   'mayer': 0.004337671004337671,
#   'marissa': 0.0038927816705594484,
#   'line': 0.0038927816705594484,
#   'get': 0.0035591146702257815,
#   'sxswi': 0.00333667000333667},
#  {'sxsw': 0.08605495075168482,
#   'mention': 0.06531881804043546,
#   'link': 0.03473302229134267,
#   'rt': 0.020736132711249352,
#   'google': 0.019699326075686883,
#   'iphone': 0.01762571280456195,
#   'apple': 0.017107309486780714,
#   'android': 0.01607050285121825,
#   'app': 0.015552099533437015,
#   'ipad': 0.013996889580093312,
#   'quot': 0.012960082944530845,
#   'store': 0.009849663037843442,
#   'new': 0.00933125972006221,
#   'austin': 0.00829445308449974,
#   'amp': 0.007776049766718507,
#   'today': 0.006220839813374806,
#   'ipad2': 0.005184033177812338,
#   'party': 0.004665629860031105,
#   'pop-up': 0.004665629860031105,
#   'get': 0.00414722654224987,
#   'circle': 0.00414722654224987,
#   'people': 0.0036288232244686366,
#   'free': 0.0036288232244686366,
#   'launch': 0.0036288232244686366,
#   'check': 0.0036288232244686366,
#   'awesome': 0.003110419906687403,
#   'apps': 0.003110419906687403,
#   'think': 0.003110419906687403,
#   'love': 0.003110419906687403,
#   'team': 0.003110419906687403},
#  {'sxsw': 0.08765232711789751,
#   'mention': 0.05799442078989869,
#   'link': 0.03685215093231537,
#   'google': 0.02275730436059316,
#   'rt': 0.019380414036118045,
#   'apple': 0.019380414036118045,
#   'ipad': 0.018499486125385406,
#   'iphone': 0.017031272940831007,
#   'quot': 0.01644398766700925,
#   'store': 0.013067097342534136,
#   'ipad2': 0.012186169431801498,
#   'new': 0.008809279107326384,
#   'austin': 0.008515636470415503,
#   'app': 0.007194244604316547,
#   'amp': 0.007194244604316547,
#   'like': 0.006019674056673029,
#   'android': 0.0052855674643958305,
#   'social': 0.0052855674643958305,
#   'circle': 0.0051387461459403904,
#   'line': 0.0051387461459403904,
#   'today': 0.004991924827484951,
#   'launch': 0.004551460872118632,
#   'pop-up': 0.003376890324475114,
#   'get': 0.0032300690060196743,
#   'free': 0.0032300690060196743,
#   'network': 0.0032300690060196743,
#   'apps': 0.003083247687564234,
#   'one': 0.003083247687564234,
#   'need': 0.002789605050653355,
#   'party': 0.002789605050653355},
#  {'sxsw': 0.08683395976122042,
#   'mention': 0.062016360822462965,
#   'link': 0.03672894096838382,
#   'rt': 0.025453239000663277,
#   'google': 0.02174994472695114,
#   'apple': 0.021086668140614637,
#   'quot': 0.01517245191244749,
#   'ipad': 0.01484081361927924,
#   'iphone': 0.014343356179526862,
#   'store': 0.013984081361927924,
#   'ipad2': 0.012740437762546982,
#   'new': 0.009064780013265532,
#   'app': 0.008677868671235905,
#   'austin': 0.008429139951359717,
#   'amp': 0.007544771169577714,
#   'android': 0.005278576166261331,
#   'launch': 0.005195666592969268,
#   'circle': 0.005112757019677205,
#   'social': 0.004891664824231705,
#   'today': 0.004477116957771391,
#   'get': 0.00436657086004864,
#   'line': 0.0041731151890338275,
#   'party': 0.004007296042449701,
#   'pop-up': 0.003979659518019014,
#   'free': 0.0035651116515587,
#   'network': 0.0035374751271280125,
#   'mobile': 0.0031782003095290738,
#   'time': 0.003150563785098386,
#   'map': 0.0029018350652221976,
#   'one': 0.0028465620163608224}]

# %%
termite_df = pd.DataFrame(overall_new)
termite_df
# Out:
#        sxsw   mention      link        rt    google     apple      quot  \
# 0  0.086334  0.064061  0.038873  0.026689  0.022166  0.020053  0.015251
# 1  0.088380  0.060837  0.037278  0.023697  0.017288  0.023004  0.014308
# 2  0.083306  0.059615  0.036703  0.025581  0.037148  0.014014  0.018129
# 3  0.086055  0.065319  0.034733  0.020736  0.019699  0.017107  0.012960
# 4  0.087652  0.057994  0.036852  0.019380  0.022757  0.019380  0.016444
# 5  0.086834  0.062016  0.036729  0.025453  0.021750  0.021087  0.015172
#
#        ipad    iphone     store  ...     mayer   marissa    people     check  \
# 0  0.014172  0.014127  0.013659  ...       NaN       NaN       NaN       NaN
# 1  0.016699  0.015833  0.015071  ...       NaN       NaN       NaN       NaN
# 2  0.013013  0.011122  0.010010  ...  0.004338  0.003893       NaN       NaN
# 3  0.013997  0.017626  0.009850  ...       NaN       NaN  0.003629  0.003629
# 4  0.018499  0.017031  0.013067  ...       NaN       NaN       NaN       NaN
# 5  0.014841  0.014343  0.013984  ...       NaN       NaN       NaN       NaN
#
#    awesome      apps    think     love     team     need
# 0      NaN       NaN      NaN      NaN      NaN      NaN
# 1      NaN       NaN      NaN      NaN      NaN      NaN
# 2      NaN       NaN      NaN      NaN      NaN      NaN
# 3  0.00311  0.003110  0.00311  0.00311  0.00311      NaN
# 4      NaN  0.003083      NaN      NaN      NaN  0.00279
# 5      NaN       NaN      NaN      NaN      NaN      NaN
#
# [6 rows x 46 columns]

# %%
termite_df.fillna(0,inplace=True)

# %%
transpose_termite_df = termite_df.T

# %%
transpose_termite_df.rename(columns={0:'Overall',
                                     1:'Apple',
                                    2:'Google',
                                    3:'Android',
                                    4:'Negative',
                                    5:'Positive'}, inplace=True)

# %%
transpose_termite_df
# Out:
#             Overall     Apple    Google   Android  Negative  Positive
# sxsw       0.086334  0.088380  0.083306  0.086055  0.087652  0.086834
# mention    0.064061  0.060837  0.059615  0.065319  0.057994  0.062016
# link       0.038873  0.037278  0.036703  0.034733  0.036852  0.036729
# rt         0.026689  0.023697  0.025581  0.020736  0.019380  0.025453
# google     0.022166  0.017288  0.037148  0.019699  0.022757  0.021750
# apple      0.020053  0.023004  0.014014  0.017107  0.019380  0.021087
# quot       0.015251  0.014308  0.018129  0.012960  0.016444  0.015172
#         0.02545324],
#        [0.02216587, 0.01728797, 0.03714826, 0.01969933, 0.0227573 ,
#         0.02174994],
#        [0.02005269, 0.02300443, 0.01401401, 0.01710731, 0.01938041,
#         0.02108667],
#        [0.01525084, 0.01430848, 0.01812924, 0.01296008, 0.01644399,
#         0.01517245],
#        [0.01417177, 0.016699  , 0.01301301, 0.01399689, 0.01849949,
#         0.01484081],
#        [0.01412681, 0.01583287, 0.01112223, 0.01762571, 0.01703127,
#         0.01434336],
#        [0.01365921, 0.01507068, 0.01001001, 0.00984966, 0.0130671 ,
#         0.01398408],
#        [0.01231937, 0.014551  , 0.00756312, 0.00518403, 0.01218617,
#         0.01274044],
#        [0.00980154, 0.0079684 , 0.01178957, 0.00933126, 0.00880928,
#         0.00906478],
#        [0.00861457, 0.00931957, 0.00700701, 0.00829445, 0.00851564,
#         0.00842914],
#        [0.00751751, 0.00665188, 0.00900901, 0.00777605, 0.00719424,
#         0.00754477],
#        [0.00738263, 0.00869595, 0.00656212, 0.0155521 , 0.00719424,
#         0.00867787],
#        [0.00621364, 0.00405349, 0.00789679, 0.00362882, 0.00455146,
#         0.00519567],
#        [0.00621364, 0.00336059, 0.00978757, 0.00414723, 0.00513875,
#         0.00511276],
#        [0.00583596, 0.00353381, 0.00912023, 0.        , 0.00528557,
#         0.00489166],
#        [0.0053324 , 0.00540466, 0.        , 0.0160705 , 0.00528557,
#         0.00527858],
#        [0.00516155, 0.00391491, 0.00611723, 0.00622084, 0.00499192,
#         0.00447712],
#        [0.00426232, 0.        , 0.00722945, 0.        , 0.00323007,
#         0.00353748],
#        [0.00409147, 0.00439994, 0.00355911, 0.00414723, 0.00323007,
#         0.00436657],
#        [0.00399255, 0.00453853, 0.00389278, 0.        , 0.00513875,
#         0.00417312],
#        [0.00379473, 0.00433065, 0.        , 0.00466563, 0.00337689,
#         0.00397966],
#        [0.00360589, 0.00346452, 0.00478256, 0.00466563, 0.00278961,
#         0.0040073 ],
#        [0.00348   , 0.00391491, 0.        , 0.00362882, 0.00323007,
#         0.00356511],
#        [0.0032462 , 0.        , 0.00544989, 0.        , 0.        ,
#         0.        ],
#        [0.00311131, 0.        , 0.00556112, 0.        , 0.        ,
#         0.0031782 ],
#        [0.00307535, 0.        , 0.00333667, 0.        , 0.        ,
#         0.        ],
#        [0.00274263, 0.00304878, 0.        , 0.        , 0.        ,
#         0.00315056],
#        [0.        , 0.00339523, 0.        , 0.        , 0.00601967,
#         0.        ],
#        [0.        , 0.00304878, 0.        , 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.00301414, 0.        , 0.        , 0.00308325,
#         0.00284656],
#        [0.        , 0.00273697, 0.        , 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.00511623, 0.        , 0.        ,
#         0.00290184],
#        [0.        , 0.        , 0.00500501, 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.00433767, 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.00389278, 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , 0.00362882, 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , 0.00362882, 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , 0.00311042, 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , 0.00311042, 0.00308325,
#         0.        ],
#        [0.        , 0.        , 0.        , 0.00311042, 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , 0.00311042, 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , 0.00311042, 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , 0.        , 0.00278961,
#         0.        ]])

# %%
col_names = list(transpose_termite_df.columns)

# %%
words = list(transpose_termite_df.index)

# %%
from textacy.viz.termite import draw_termite_plot

# %%
draw_termite_plot(mat,col_names,words,highlight_cols=range(0,5))
